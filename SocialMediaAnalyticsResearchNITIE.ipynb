# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn 
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import  LogisticRegression
from sklearn.tree import  DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import  LinearDiscriminantAnalysis 
from sklearn.naive_bayes import  GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("C:/Users/jivitesh's PC/Desktop/Indian Elections/General Elections/constituency_wise_detailed_results/2014.csv")
#df.head()
df.info()
#df2=df.dropna(axis=0,inplace=True)
#df.info()
df.PARTY
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8355 entries, 0 to 8354
# Data columns (total 14 columns):
# TERRITORY                   8355 non-null object
# CONSTITUENCY                8355 non-null object
# CANDIDATE                   8355 non-null object
# SEX                         7845 non-null object
# AGE                         7845 non-null float64
# CATEGORY                    7845 non-null object
# PARTY                       8355 non-null object
# PARTY SYMBOL                8355 non-null object
# GENERALVOTESSECURED         8355 non-null int64
# POSTALVOTESSECURED          8355 non-null int64
# TOTALVOTESSECURED           8355 non-null int64
# PERCENTAGEOFTOTALVOTES      8355 non-null float64
# PERCENTAGEOFTOTAL POLLED    8355 non-null float64
# TOTALELECTORS               8355 non-null int64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 913.9+ KB
# 0              TRS
# 1              INC
# 2              TDP
# 3              BSP
# 4              IND
# 5              IND
# 6              IND
# 7              IND
# 8             NOTA
# 9              TDP
# 10             BSP
# 11             TRS
# 12             INC
# 13            PPOI
# 14             RPI
# 15            BCUF
# 16             NIP
# 17            MaSP
# 18           RP(K)
# 19             IND
# 20             IND
# 21             IND
# 22             IND
# 23             IND
# 24             IND
# 25             IND
# 26            NOTA
# 27             BJP
# 28             INC
# 29             NCP
#            ...
# 8325         AINRC
# 8326          ADMK
# 8327           BSP
# 8328           INC
# 8329           DMK
# 8330           CPI
# 8331         JD(U)
# 8332    CPI(ML)(L)
# 8333           SAP
# 8334          AAAP
# 8335           IND
# 8336           IND
# 8337           IND
# 8338           IND
# 8339           IND
# 8340           IND
# 8341           IND
# 8342           IND
# 8343           IND
# 8344           IND
# 8345           IND
# 8346           IND
# 8347           IND
# 8348           IND
# 8349           IND
# 8350           IND
# 8351           IND
# 8352           IND
# 8353           IND
# 8354          NOTA
# Name: PARTY, Length: 8355, dtype: object

# %%
df=pd.read_csv("C:/Users/jivitesh's PC/Desktop/Indian Elections/General Elections/constituency_wise_detailed_results/2014.csv")
#df.head()
#df.info()
#df2=df.dropna(axis=0,inplace=True)
#df.info()
df.PARTY
PartyOrderedNames=[]
PartiesTotalVotes={}
UniquePartyArray=[i for i in set(df.PARTY)]
AllIndexes={}
np.asarray(UniquePartyArray)

for i in UniquePartyArray:
    PartiesTotalVotes[i]=0





for i in range (len(df.PARTY)):
        PartyOrderedNames.append(df.PARTY[i])
np.asarray(PartyOrderedNames)

for i in PartiesTotalVotes.keys():
    AllIndexes[i]=np.where(df.PARTY==i)[0]
    
def SumTotal(target):
    for x in AllIndexes[target]:
        PartiesTotalVotes[target]=PartiesTotalVotes[target]+df.TOTALVOTESSECURED[x]
    return PartiesTotalVotes
         
for i in UniquePartyArray:
    for j in df.PARTY:
        if i==j:
            SumTotal(j)
          

        
        
# %%
Top_ten=pd.DataFrame({"PartyName":[i for i in CopyOfDict.keys()],"PartyVotes":[i for i in CopyOfDict.values()]})
Top_ten.sort_values(by=["PartyVotes"],ascending=False,inplace=True)
OriginalTopTen=Top_ten.head(10)
Labels=[]
ArrayLabels=(np.asarray(OriginalTopTen.PartyName))
X_axis=np.arange(len(OriginalTopTen.PartyName))



plt.figure(figsize=(20,10))
plt.bar(X_axis,OriginalTopTen.PartyVotes)
plt.xlabel("Top 10 Party Names")
plt.ylabel("Total Votes in  Hundred Millions")
plt.xticks(X_axis,ArrayLabels)
plt.show()

# %% [markdown]
# # 2009 dataset

# %%
df=pd.read_csv("C:/Users/jivitesh's PC/Desktop/Indian Elections/General Elections/constituency_wise_detailed_results/2009.csv")
#df.head()
#df.info()
#df2=df.dropna(axis=0,inplace=True)
#df.info()
df.PARTY
PartyOrderedNames2009=[]
PartiesTotalVotes2009={}
UniquePartyArray2009=[i for i in set(df.PARTY)]
AllIndexes2009={}
np.asarray(UniquePartyArray2009)

for i in UniquePartyArray2009:
    PartiesTotalVotes2009[i]=0





for i in range (len(df.PARTY)):
        PartyOrderedNames2009.append(df.PARTY[i])
np.asarray(PartyOrderedNames2009)

for i in PartiesTotalVotes2009.keys():
    AllIndexes2009[i]=np.where(df.PARTY==i)[0]
    
def SumTotal(target):
    for x in AllIndexes2009[target]:
        PartiesTotalVotes2009[target]=PartiesTotalVotes2009[target]+df.TOTALVOTES[x]
    return PartiesTotalVotes2009
         
for i in UniquePartyArray2009:
    for j in df.PARTY:
        if i==j:
            SumTotal(j)
          

        
        
for i in PartiesTotalVotes2009.keys():
    PartiesTotalVotes2009[i]=PartiesTotalVotes2009[i]/PartyOrderedNames2009.count(i)

PartiesTotalVotes2009
CopyOfDict2009=PartiesTotalVotes2009.copy()

# %%
 print(CopyOfDict2009)
# Out:
# {'AC': 46539.0, 'PMSP': 57649.0, 'UCPI': 1713.0, 'JANS': 226.0, 'BJTP': 6872.0, 'ACNC': 40204.0, 'RTKP': 55805.0, 'ANC': 60896.0, 'ADSMK': 1189.0, 'MUL': 877494.0, 'RLD': 1821054.0, 'MBP': 1006.0, 'MJP': 245174.0, 'DBP': 531.0, 'BMF': 13737.0, 'JKM': 12716.0, 'JPC': 65403.0, 'BHBP': 39797.0, 'NCP': 8521502.0, 'BREM': 42386.0, 'ABJS': 20599.0, 'SKP': 60333.0, 'UGDP': 16727.0, 'ABMSD': 26268.0, 'PPA': 5996.0, 'RSP': 1573650.0, 'BRM': 867.0, 'BNJD': 7194.0, 'YFE': 2099.0, 'JP': 1514.0, 'MAP': 1816.0, 'NELU': 27388.0, 'PRCP': 76518.0, 'BHSAS': 15718.0, 'ARP': 6672.0, 'RAD': 4072.0, 'JMM': 1665173.0, 'RVP': 584.0, 'PRBP': 11341.0, 'SHRP': 4639.0, 'BUM': 15272.0, 'BSP(K)': 33010.0, 'ABKMM': 305.0, 'VHS': 935.0,
': 104600.0, 'AIRP': 678.0, 'MB(S)P': 910.0, 'RVNP': 34670.0, 'LB': 9407.0, 'BSKRP': 5068.0, 'KVSP': 10447.0, 'ABLTP': 578.0, 'MCO': 91489.0, 'RP(K)': 11724.0, 'RPIE': 12767.0, 'SVPP': 2275.0, 'UKKD': 38633.0, 'RJAP': 1394.0, 'HDVP': 532.0, 'RALOP': 2021.0, 'CPI': 5951888.0, 'JDP': 102698.0, 'LSP': 557376.0, 'AGP': 1773103.0, 'MNS': 1503863.0, 'AIMIM': 308061.0, 'JJJKMC': 1100.0, 'HJP': 7054.0, 'LBP': 118470.0, 'PDA': 224719.0, 'PBHP': 4810.0, 'AP': 4386.0, 'ASDC': 123287.0, 'PMK': 1944619.0, 'RSMD': 153455.0, 'VVS': 837.0, 'BPD': 14974.0, 'RPP': 29151.0, 'HJCBL': 816395.0, 'JHJAM': 32219.0, 'GMS': 85355.0, 'RPI': 294650.0, 'AJSP': 2678.0, 'MKD': 1106.0, 'IUML': 7553.0, 'IBSP': 1780.0, 'LKJP': 351.0, 'KOKD': 42744.0, 'BJD': 6612552.0, 'BJKVP': 11097.0, 'IJP': 177759.0, 'BSD': 5565.0, 'MMKA': 16699.0, 'SWP': 481025.0, 'BEP': 8105.0, 'AIJMK': 21609.0, 'NDEP': 2787.0, 'JBSP': 4967.0, 'PPIS': 578.0, 'BVP': 1435.0, 'VAJP': 17868.0, 'IPP': 18726.0, 'LJP': 1891963.0, 'RDSD': 484.0, 'BHPP': 5226.0, 'CGVP': 18394.0, 'RYS': 482.0, 'DCP': 2497.0, 'INC': 119111019.0, 'UWF': 12338.0, 'MDP': 8946.0, 'SWJP': 23539.0, 'LKSP': 11893.0, 'SBSP': 319307.0, 'ABCD(A': 22861.0, 'BRP': 1407.0, 'BJBCD': 4307.0, 'PLP': 1243.0, 'BJP': 78435381.0, 'JKANC': 9900.0, 'BSA': 18844. ...

# %%
Top_ten2009=pd.DataFrame({"PartyName":[i for i in CopyOfDict2009.keys()],"PartyVotes":[i for i in CopyOfDict2009.values()]})
Top_ten2009.sort_values(by=["PartyVotes"],ascending=False,inplace=True)
OriginalTopTen2009=Top_ten2009.head(10)
Labels2009=[]
ArrayLabels2009=(np.asarray(OriginalTopTen2009.PartyName))
X_axis2009=np.arange(len(OriginalTopTen2009.PartyName))



plt.figure(figsize=(20,10))
plt.bar(X_axis2009,OriginalTopTen2009.PartyVotes)
plt.xlabel("Top 10 Party Names")
plt.ylabel("Total Votes in  Hundred Millions")
plt.xticks(X_axis2009,ArrayLabels2009)
plt.show()

# %%
df=pd.read_csv("C:/Users/jivitesh's PC/Desktop/Indian Elections/General Elections/VOTING_RESULTS_2019.csv")
#df.head()
#df.info()
#df2=df.dropna(axis=0,inplace=True)
#df.info()
df.PARTY
PartyOrderedNames2019=[]
PartiesTotalVotes2019={}
UniquePartyArray2019=[i for i in set(df.PARTY)]
AllIndexes2019={}
np.asarray(UniquePartyArray2019)

for i in UniquePartyArray2019:
    PartiesTotalVotes2019[i]=0





for i in range (len(df.PARTY)):
        PartyOrderedNames2019.append(df.PARTY[i])
np.asarray(PartyOrderedNames2019)

for i in PartiesTotalVotes2019.keys():
    AllIndexes2019[i]=np.where(df.PARTY==i)[0]
    
def SumTotal(target):
    for x in AllIndexes2019[target]:
        PartiesTotalVotes2019[target]=PartiesTotalVotes2019[target]+df.TOTAL_VOTES[x]
    return PartiesTotalVotes2019
         
for i in UniquePartyArray2019:
    for j in df.PARTY:
        if i==j:
            SumTotal(j)
          

        
        
for i in PartiesTotalVotes2019.keys():
    PartiesTotalVotes2019[i]=PartiesTotalVotes2019[i]/PartyOrderedNames2019.count(i)

PartiesTotalVotes2019
CopyOfDict2019=PartiesTotalVotes2019.copy()

# %%
# Out:
# {'AARAKSHAN VIRODHI PARTY': 7697.0,
#  'AJSU Party': 648277.0,
#  'Aadarsh Janata Sewa Party': 551.0,
#  'Aadarsh Mithila Party': 11311.0,
#  'Aadarsh Sangram Party': 4283.0,
#  'Aajad Bharat Party (Democratic)': 16481.0,
#  'Aam Aadmi Party': 3130190.0,
#  'Aam Adhikar Morcha': 34845.0,
#  'Aam Janta Party (India)': 16749.0,
#  'Aam Janta Party Rashtriya': 19924.0,
#  'Aap Aur Hum Party': 3434.0,
#  'Aapki Apni Party (Peoples)': 19333.0,
#  'Aasra Lokmanch Party': 4856.0,
#  'Adarsh Nyay Rakshak Party': 2360.0,
#  'Adarsh Samaj Party': 3423.0,
#  'Adarshwaadi Congress Party': 838.0,
#  'Adhikar Vikas Party': 3526.0,
#  'Adhunik Bharat Party': 1976.0,
#  'Adim Bhartiya Dal': 716.0,
#  'Agila India Makkal Kazhagam': 7320.0,
#  'Ahila India Dhayaga Makkal Munnetra Katchi': 1765.0,
#  'Ahimsa Socialist Party': 972.0,
#  'Ahinsa Samaj Party': 1424.0,
#  'Aihra National Party': 50071.0,
#  'Akhand Hind Party': 3907.0,
#  'Akhand Rashtrawadi Party': 2626.0,
#  'Akhand Samaj Party': 7569.0,
#  'Akhil Bharat Hindu Mahasabha': 23475.0,
#  'Akhil Bharat Samagra Kranti Party': 9912.0,
#  'Akhil Bharatiya Jan Sangh': 9015.0,
#  'Akhil Bharatiya Manavata Paksha': 885.0,
#  'Akhil Bharatiya Muslim League (Secular)': 5179.0,
#  'Akhil Bharatiya Sena': 1567.0,
#  'Akhil Bhartiya Apna Dal': 12538.0,
#  'Akhil Bhartiya Ekata Party': 1006.0,
#  'Akhil Bhartiya Gondwana Party': 48426.0,
#  'Akhil Bhartiya Jharkhand Party': 8484.0,
#  'Akhil Bhartiya Lok Dal': 503.0,
#  'Akhil Bhartiya Mithila Party': 10127.0,
#  'Akhil Bhartiya Navnirman Party': 2759.0,
#  'Akhil Bhartiya Sarvadharma Samaj Party': 735.0,
#  'Akhil Hind Forward Bloc (Krantikari)': 23252.0,
#  'Akila India Vallalar Peravai': 643.0,
#  'Al-Hind Party': 1764.0,
#  'All  India Puratchi Thalaivar Makkal Munnettra Kazhagam': 2764.0,
#  'All India Anna Dravida Munnetra Kazhagam': 7830520.0,
#  'All India Forward Bloc': 318674.0,
#  'All India Hindustan Congress Party': 8082.0,
#  'All India Jana Andolan Party': 6495.0,
#  'All India Labour Party': 2707.0,
#  'All India Majlis-E-Ittehadul Muslimeen': 1201542.0,
#  'All India Minorities Front': 1850.0,
#  'All India N.R. Congress': 247956.0,
#  "All India Peoples' Front (Radical)": 11032.0,
#  'All India Praja Party': 2023.0,
#  'All India Trinamool Congress': 24929325.0,
#  'All India Ulama Congress': 4024.0,
#  'All India United Democratic Front': 1402088.0,
#  'All India Uzhavargal Uzhaippalargal Katchi': 1999.0,
#  'All Indian Rajiv Congress Party': 1282.0,
#  'All Indians Party': 396.0,
#  'All Pensioner’s Party': 892.0,
#  'All Peoples Party': 370.0,
#  'Ambedkar National Congress': 49149.0,
#  'Ambedkar Samaj Party': 35076.0,
#  'Ambedkar Yug Party': 921.0,
#  'Ambedkarist Republican Party': 4399.0,
#  'Ambedkarite Party of India': 381070.0,
#  'Amra Bangalee': 36570.0,
#  'Anaithu Makkal Katchi': 645.0,
#  'Anaithu Makkal Puratchi Katchi': 5089.0,
#  'Andaman & Nicobar Janta Party': 2017.0,
#  'Andhra Chaitanya Party': 1263.0,
#  'Andhra Rastra Praja Samithi': 1563.0,
#  'Anjaan Aadmi Party': 1281.0,
#  'Anna YSR Congress Party': 5511.0,
#  'Annadata Party': 5147.0,
#  'Anti Corruption Dynamic Party': 40214.0,
#  'Apna Dal (Soneylal)': 1039478.0,
#  'Apna Dal United Party': 8541.0,
#  'Apna Desh Party': 5682.0,
#  'Apna Kisan Party': 8354.0,
#  'Apna Samaj Party': 3678.0,
#  'Asli Deshi Party': 11598.0,
#  'Asom Gana Parishad': 1480697.0,
#  'Asom Jana Morcha': 21678.0,
#  'Assam Dristi Party': 8285.0,
#  'Atulya Bharat Party': 4737.0,
#  'Autonomous State Demand Committee': 36915.0,
#  'Awami Samta Party': 5504.0,
#  'Azad Mazdoor Kissan Party': 829.0,
#  'B. C. United Front': 649.0,
#  'Bahujan Awam Party': 14060.0,
#  'Bahujan Azad Party': 8421.0,
#  'Bahujan Maha Party': 46185.0,
#  'Bahujan Mukti Party': 411681.0,
#  'Bahujan Nyay Dal': 26746.0,
#  'Bahujan Republican  Socialist Party': 54266.0,
#  'Bahujan Samaj Party': 22290771.0,
#  'Bahujan Samaj Party  (Ambedkar)': 6802.0,
#  'Bahujan Samyak Party (Mission)': 501.0,
#  'Bahujan Suraksha Dal': 743.0,
#  'Bahujan Vikas Aaghadi': 491596.0,
#  'Bahujana Raajyam Party (Phule Ambedkar)': 1008.0,
#  'Bajjikanchal Vikas Party': 40906.0,
#  'Baliraja Party': 24915.0,
#  'Bhapase Party': 1434.0,
#  'Bharat Bhoomi Party': 6730.0,
#  'Bharat Bhrashtachar Mitao Party': 9894.0,
#  'Bharat Jan Aadhar Party': 3919.0,
#  'Bharat Lok Sewak Party': 3271.0,
#  'Bharat Nirman Party': 5674.0,
#  'Bharat Prabhat Party': 93486.0,
#  'Bharat Rakshak Party (Democratic)': 2880.0,
#  'Bharateeya Manavadhikar party': 6511.0,
#  'Bharath Dharma Jana Sena': 380847.0,
#  'Bharatiya Aam Awam Party': 9628.0,
#  'Bhartiya Sarvodaya Party': 3638.0,
#  'Bhartiya Shakti Chetna Party': 109487.0,
#  'Bhartiya Tribal Party': 539319.0,
#  'Bhartiya Vanchitsamaj Party': 984.0,
#  'BhartiyaBahujanKranti Dal': 6684.0,
#  'Bihar Lok Nirman Dal': 31494.0,
#  'Biju Janata Dal': 10172041.0,
#  'Bodoland Peoples Front': 446774.0,
#  'Bundelkhand Kranti Dal': 1849.0,
#  'Challengers Party': 958.0,
#  'Chandigarh Ki Aawaz Party': 3186.0,
#  'Chhattisgarh Swabhiman Manch': 2691.0,
#  'Chhattisgarh Vikas Ganga Rashtriya Party': 5540.0,
#  'Christian Democratic Front': 494.0,
#  'Communist Party of India': 3709997.0,
#  'Communist Party of India  (Marxist)': 10744779.0,
#  'Communist Party of India  (Marxist-Leninist)  (Liberation)': 714481.0,
#  'Communist Party of India (Marxist-Leninist) Red Star': 90645.0,
#  'Corruption Abolition Party': 275.0,
#  'Daksha Party': 346.0,
#  'Dalit Soshit Pichhara Varg  Adhikar Dal': 3522.0,
#  'Dalita Bahujana Party': 6133.0,
#  'Democratic Corruption Liberation Front': 596.0,
#  'Democratic Party of India': 499.0,
#  'Democratic Party of India (Ambedkar)': 4913.0,
#  'Democratic Prajakranthi Party Secularist': 429.0,
#  'Desh Janhit Party': 273.0,
#  'Desiya Makkal Sakthi Katchi': 14300.0,
#  'Desiya Murpokku Dravida Kazhagam': 929590.0,
#  'Desiya Uzhavar Uzhaipalar Kazhagam': 3337.0,
#  'Dogra Swabhiman Sangathan Party,': 1263.0,
#  'Dr. Bhimrao Ambedkar Dal': 1549.0,
#  'Dravida Munnetra Kazhagam': 13877622.0,
#  'Ekta Samaj Party': 1270.0,
#  'Engineers Party': 1442.0,
#  'Ezhuchi Tamilargal Munnetra Kazhagam': 5482.0,
#  'Fauji Janta Party': 564.0,
#  'Forward Democratic Labour Party': 1519.0,
#  'Freethought Party of India': 6884.0,
#  'Ganasangam Party of India': 11631.0,
#  'Gareeb Aadmi Party': 385.0,
#  'Garib Janshakti Party': 11678.0,
#  'Garvi Gujarat Party': 10469.0,
#  'Gondvana Gantantra Party': 210088.0,
#  'Gorkha Rashtriya Congress': 2952.0,
#  'Gujarat Janta Panchayat Party': 1524.0,
#  'Hamari Apni Party': 847.0,
#  'Hamro Sikkim Party': 1998.0,
#  'Hardam Manavtawadi Rashtriya Dal': 447.0,
#  'Himachal Jan Kranti Party': 970.0,
#  'Hind Congress Party': 2094.0,
#  'Hindu Samaj Party': 1014.0,
#  'Hindustan Janta Party': 9997.0,
#  'Hindustan Shakti Sena': 25662.0,
#  'Hindustani Awam Morcha (Secular)': 956501.0,
#  'Hindusthan Nirman Dal': 121711.0,
#  'Hindusthan Praja Paksha': 3750.0,
#  'Hum Bhartiya Party': 16672.0,
#  'Hum Sabki Party': 1432.0,
#  'Ilantamilar Munnani Kazhagam': 748.0,
#  'Independent': 16273403.0,
#  'Independent People’s Party': 15.0,
#  'India Praja Bandhu Party': 20682.0,
#  'Indian Christian Front': 4832.0,
#  'Indian Democratic Republican Front': 7784.0,
#  'Indian Gandhiyan Party': 824.0,
#  'Indian Indira Congress (R)': 2569.0,
#  'Indian Labour Party (Ambedkar Phule)': 4923.0,
#  'Indian National Congress': 118787724.0,
#  'Indian National League': 3644.0,
#  'Indian National Lok Dal': 300937.0,
#  'Indian New Congress Party': 21095.0,
#  'Indian Peoples Green Party': 9538.0,
#  'Indian Rakshaka Nayakudu Party': 2012.0,
#  'Indian Union Muslim League': 1592467.0,
#  'Indian Unity Centre': 4003.0,
#  "Indigenous People's Front of Tripura": 89529.0,
#  'Inqalab Vikas Dal': 718.0,
#  'Jago Hindustan Party': 6171.0,
#  'Jai Jawan Jai Kisan Party': 4809.0,
#  'Jai Lok Party': 473.0,
#  'Jai Maha Bharath Party': 3267.0,
#  'Jai Prakash Janata Dal': 27404.0,
#  'Jai Swaraj Party': 1056.0,
#  'Jai Vijaya Bharathi Party': 696.0,
#  'Jamat-E-Seratul Mustakim': 5885.0,
#  'Jammu & Kashmir National Conference': 759.0,
#  'Jammu & Kashmir National Panthers Party': 2817.0,
#  'Jammu & Kashmir People Conference': 186.0,
#  'Jammu & Kashmir Peoples Democratic Party': 524.0,
#  'Jammu & Kashmir Pir Panjal Awami Party': 28.0,
#  'Jan Adesh Akshuni Sena': 1812.0,
#  'Jan Adhikar Party': 73639.0,
#  'Jan Adhikar Party (Loktantrik)': 97631.0,
#  'Jan Samman party': 3706.0,
#  'Jan Sangh Party': 712.0,
#  'Jan Sangharsh Virat Party': 10569.0,
#  'Jan Satya Path Party': 3646.0,
#  'Jan Seva Sahayak Party': 3731.0,
#  'Jan Shakti Dal': 5758.0,
#  'Jan Shakti Ekta Party': 1557.0,
#  'Jana Jagruti Party': 11464.0,
#  'Janapaalana Party (Democratic)': 913.0,
#  'Janasena Party': 1915127.0,
#  'Janata Congress': 14595.0,
#  'Janata Dal  (Secular)': 3457107.0,
#  'Janata Dal  (United)': 8327795.0,
#  'Janata Party': 13467.0,
#  'Janhit Bharat Party': 7192.0,
#  'Janhit Kisan Party': 28719.0,
#  'Jannayak Janta Party': 688483.0,
#  'Janral Samaj Party': 18699.0,
#  'Jansatta Dal Loktantrik': 203369.0,
#  'Jansatta Party': 2484.0,
#  'Janta Dal Rashtravadi': 27584.0,
#  'Janta Kranti Party (Rashtravadi)': 4873.0,
#  'Janta Raj Party': 2308.0,
#  'Janta Raj Vikas Party': 2364.0,
#  'Jantantrik Vikas Party': 17955.0,
#  'Janvadi Party(Socialist)': 2640.0,
#  'Jharkhand Anushilan Party': 4164.0,
#  'Jharkhand Mukti Morcha': 1901976.0,
#  'Jharkhand Mukti Morcha  (Ulgulan)': 8672.0,
#  'Jharkhand Party': 35060.0,
#  'Jharkhand Party  (Naren)': 18869.0,
#  'Jharkhand Party (Secular),': 1244.0,
#  "Jharkhand People's Party": 16195.0,
#  'Jharkhand Vikas Morcha (Prajatantrik)': 750799.0,
#  'Jwala Dal': 1572.0,
#  'Kalinga Sena': 12430.0,
#  'Kalyankari Jantantrik Party': 1336.0,
#  'Kamatapur People’s Party (United)': 12666.0,
#  'Kannada Chalavali Vatal Paksha': 2510.0,
#  'Kanshiram Bahujan Dal': 7255.0,
#  'Karnataka Jantha Paksha': 2013.0,
#  'Karnataka Karmikara Paksha': 3084.0,
#  'Karnataka Pragnyavantha Janatha Party': 1207.0,
#  'Karnataka Praja Party (RaithaParva)': 3697.0,
#  'Kartavya Rashtriya Party': 512.0,
#  'Kerala Congress': 155135.0,
#  'Kerala Congress  (M)': 421046.0,
#  'Khusro Sena Party': 687.0,
#  'Kisan Majdoor Berojgar Sangh': 1574.0,
#  'Kisan Mazdoor Sangharsh Party': 7974.0,
#  'Kisan Party of India': 5647.0,
#  'Kisan Raj Party,': 2426.0,
#  'Kisan Raksha Party,': 3303.0,
#  'Kranti Kari Jai Hind Sena': 11200.0,
#  'Krupaa Party': 8507.0,
#  'Lok  Chetna  Dal': 2384.0,
#  'Lok Dal': 18218.0,
#  'Lok Gathbandhan Party': 18684.0,
#  'Lok Insaaf Party': 489871.0,
#  'Lok Jan Sangharsh Party': 968.0,
#  'Lok Jan Shakti Party': 3206979.0,
#  'Lok Jan Vikas Morcha': 9278.0,
#  'Lokjagar Party': 1135.0,
#  'Lokpriya Samaj Party': 478.0,
#  'Loksangram': 8418.0,
#  'Loktanter Suraksha Party': 55280.0,
#  'Loktantrik Jan Swaraj Party': 9868.0,
#  'Loktantrik Janshakti Party': 2725.0,
#  'Loktantrik Rashrtavadi Party': 705.0,
#  'Maanavvaadi Janta Party': 6267.0,
#  'Madhya Pradesh Jan Vikas Party': 15472.0,
#  'Mahamukti Dal': 2477.0,
#  'Maharashtra Kranti Sena': 2761.0,
#  'Maharashtra Swabhimaan Paksh,': 281578.0,
#  'Mahasankalp Janta Party': 2427.0,
#  'Mahila & Yuva Shakti Party': 605.0,
#  'Majdoor Kisan Union Party': 687.0,
#  'Makkal Needhi Maiam': 1613688.0,
#  'Makkal Sananayaga Kudiyarasu Katchi,': 2906.0,
#  'Makkalatchi Katchi': 1115.0,
#  'Manav Kranti Party': 1344.0,
#  'Manavtawadi Samaj Party': 4498.0,
#  "Manipur Democratic Peoples's Front": 2512.0,
#  'Manipur People’s Party': 3566.0,
#  'Manuvadi Party': 3962.0,
#  'Manvadhikar National Party': 1900.0,
#  'Marxist Communist Party of India (United)': 21045.0,
#  'Marxist Leninist Party of India (Red Flag)': 14016.0,
#  'Mazdoor Dalit Kisaan Mahila Gareeb Party (Hindustani)': 1669.0,
#  'Mazdoor Kirayedar Vikas Party': 5017.0,
#  'Mera Adhikaar Rashtriya Dal': 973.0,
#  'Minorities Democratic Party': 6198.0,
#  'Mithilanchal Mukti Morcha': 4413.0,
#  'Mizo National Front': 224286.0,
#  'Moolniwasi Samaj Party': 21234.0,
#  'Moulik Adhikar Party': 59235.0,
#  'Mulnibasi Party of India': 4057.0,
#  'Mundadugu Praja Party': 7342.0,
#  'Naam Indiar Party': 2596.0,
#  'Naam Tamilar Katchi': 1668042.0,
#  'Nagrik Ekta Party': 18037.0,
#  'Naitik Party': 7294.0,
#  'National Apni Party': 1044.0,
#  'National Bhrashtachar Mukt Party': 1453.0,
#  'National Dalitha Dhal Party': 628.0,
#  'National Development Party': 1138.0,
#  'National Fifty Fifty Front': 1308.0,
#  'National Jagaran Party': 4444.0,
#  'National Labour Party': 2833.0,
#  'National Lokmat Party': 1628.0,
#  'National Nava Kranthi Party': 887.0,
#  "National People's Party": 395260.0,
#  'National Republican Congress': 4278.0,
#  "National Women's Party": 3903.0,
#  'National Youth Party': 1053.0,
#  'Nationalist Congress Party': 8497779.0,
#  'Nationalist Democratic Progressive Party': 500510.0,
#  'Nationalist Janshakti Party': 4847.0,
#  'Nationalist Justice Party': 6531.0,
#  "Nationalist People's Front": 5798.0,
#  'Nava Praja Rajyam Party': 8007.0,
#  'Nava Samaj Party': 4286.0,
#  'Navarang Congress Party': 1564.0,
#  'Navataram Party': 1135.0,
#  'Navbharat Ekta Dal': 2371.0,
#  'Navbharat Nirman Party': 4590.0,
#  'Navnirman Party': 1970.0,
#  'Navodayam Party': 1341.0,
#  'Navsarjan Bharat Party': 1160.0,
#  'Nawan Punjab Party': 161645.0,
#  'Netaji Subhash Chander Bose Rashtriya Azad Party': 2342.0,
#  'New All India Congress Party': 3391.0,
#  'New Democratic Party of India': 7081.0,
#  'New India Party': 1059.0,
#  'Nirbhay Bharteey Party': 2449.0,
#  'North East India Development Party': 50020.0,
#  'Odisha Pragati Dal': 8304.0,
#  'Parivartan Samaj Party': 6469.0,
#  'Party for Democratic Socialism': 12087.0,
#  'Pattali Makkal Katchi': 2297431.0,
#  'Peace Party': 29998.0,
#  "People's Party of Arunachal": 27703.0,
#  "People's Party of India(secular)": 4914.0,
#  'Peoples Democratic Party': 3236.0,
#  'Peoples Party of India (Democratic)': 155416.0,
#  'Peoples Representation for Identity and Status of Mizoram (PRISM) Party': 13323.0,
#  'People’s Union Party': 547.0,
#  'Pichhara Samaj Party United': 8884.0,
#  'Pichhra Samaj Party': 4073.0,
#  'Poorvanchal Rashtriya Congress': 10532.0,
#  'Prabuddha Republican Party': 13229.0,
#  'Pragatisheel Lok Manch': 3339.0,
#  'Pragatisheel Manav Samaj Party': 8210.0,
#  'Pragatisheel Samaj Party': 11752.0,
#  'Pragatishil Samajwadi Party (Lohia)': 345452.0,
#  'Prahar Janshakti Party': 20620.0,
#  'Praja Satta Party': 1462.0,
#  'Praja Shanthi Party': 9738.0,
#  'Prajaa Swaraaj Party': 4179.0,
#  'Prajatantra Aadhar Party': 1346.0,
#  'Prajatantrik Samadhan Party': 4612.0,
#  'Pravasi Nivasi Party': 1695.0,
#  'Prem Janata Dal': 1223.0,
#  'Prism': 1400.0,
#  'Prithviraj Janshakti Party': 5451.0,
#  'Proutist Bloc, India': 19457.0,
#  'Proutist Sarva Samaj': 13535.0,
#  'Public Mission Party': 13238.0,
#  'Puducherry Development  Party': 1319.0,
#  'Punjab Ekta Party': 296620.0,
#  'Punjab Labour Party': 692.0,
#  'Purvanchal Janta Party (Secular)': 43892.0,
#  'Purvanchal Mahapanchayat': 13450.0,
#  'Pyramid Party of India': 77164.0,
#  'RASHTRIYA VIKLANG PARTY': 3845.0,
#  'Radical Democrats': 1220.0,
#  'Raita Bharat Party': 811.0,
#  'Rashtriya Pragati Party': 2718.0,
#  'Rashtriya Praja Congress  (Secular)': 996.0,
#  'Rashtriya Rashtrawadi Party': 20704.0,
#  'Rashtriya Sahara Party': 4976.0,
#  'Rashtriya Sahyog Party': 2756.0,
#  'Rashtriya Samaj Paksha': 28545.0,
#  'Rashtriya Samajwadi Party  (Secular)': 3926.0,
#  'Rashtriya Samanta Dal': 6918.0,
#  'Rashtriya Samrasta Party': 1648.0,
#  'Rashtriya Samta Party (Secular)': 58110.0,
#  'Rashtriya Samta Vikas Party': 349.0,
#  'Rashtriya Sangail Party': 3895.0,
#  'Rashtriya Sarvjan Vikas Party': 6497.0,
#  'Rashtriya Shoshit Samaj Party': 30983.0,
#  'Rashtriya Ulama Council': 25756.0,
#  'Rashtriya Vikas Party': 477.0,
#  'Rashtriya Vyapari Party': 1326.0,
#  'Rashtriya mahan Gantantra Party': 16371.0,
#  'Rastriya Aam Jan Seva Party': 1425.0,
#  'Rastriya Insaaf Party': 3265.0,
#  'Rayalaseema Rashtra Samithi': 1223.0,
#  'Real Democracy Party': 532.0,
#  'Republican Bahujan Sena': 1820.0,
#  'Republican Paksha (Khoripa)': 1506.0,
#  'Republican Party of India': 12478.0,
#  'Republican Party of India  (Kamble)': 2809.0,
#  'Republican Party of India (A)': 71524.0,
#  'Republican Party of India (Karnataka)': 14746.0,
#  'Republican Party of India (Khobragade)': 4402.0,
#  'Republican Party of India (Reformist)': 1777.0,
#  'Republican Sena': 5654.0,
#  'Revolutionary Marxist Party of India': 17125.0,
#  'Revolutionary Socialist Party': 709685.0,
#  'Right to Recall Party': 28817.0,
#  'SOCIAL DEMOCRATIC PARTY OF INDIA': 169654.0,
#  'SOCIALIST UNITY CENTRE OF INDIA (COMMUNIST)': 403835.0,
#  'Saaf Party': 882.0,
#  'Sabhi Jan Party': 2751.0,
#  'Sabka Dal United': 6283.0,
#  'Sabse Achchhi Party': 1360.0,
#  'Sajag Samaj Party': 2041.0,
#  'Samaanya Praja Party': 4983.0,
#  'Samagra Utthan Party': 24816.0,
#  'Samaj Adhikar Kalyan Party': 6736.0,
#  'Samaj Bhalai Morcha': 2917.0,
#  'Samajik Nyaya Party': 5027.0,
#  'Samajtantric Party of India': 730.0,
#  'Samajwadi Forward Bloc': 18571.0,
#  'Samajwadi Jan Parishad': 1899.0,
#  'Samajwadi Janata Dal Democratic': 25630.0,
#  'Samajwadi Janata Party(Karnataka)': 4991.0,
#  'Samajwadi Party': 15261257.0,
#  'Samajwadi Samaj Party': 2417.0,
#  'Saman Aadmi Saman Party': 6368.0,
#  'Samata Kranti Dal': 3877.0,
#  'Samata Samadhan Party': 9396.0,
#  'Samdarshi Samaj Party': 3139.0,
#  'Samrat Ashok Sena Party': 2214.0,
#  'Samta Vikas Party': 2688.0,
#  'Sanatan Sanskriti Raksha Dal': 7325.0,
#  'Sangharsh Sena': 1987.0,
#  'Sanjhi Virasat Party': 419.0,
#  'Sankhyanupati Bhagidari Party': 6395.0,
#  'Sanman Rajkiya Paksha': 1961.0,
#  'Sanyukt Vikas Party': 8205.0,
#  'Sapaks Party': 33366.0,
#  'Sardar Vallabhbhai Patel Party': 14882.0,
#  'Sarv Vikas Party': 688.0,
#  'Sarva Janata Party': 14213.0,
#  'Sarvadharam Party (Madhya Pradesh)': 12525.0,
#  'Sarvjan Lok Shakti Party': 2554.0,
#  'Sarvjan Sewa Party': 1085.0,
#  'Sarvodaya Bharat Party': 20764.0,
#  'Sarvodaya Prabhat Party': 740.0,
#  'Sarvshreshth Dal': 2901.0,
#  'Sathi Aur Aapka Faisala Party': 8643.0,
#  'Satya Bahumat Party': 22560.0,
#  'Secular Democratic Congress': 5321.0,
#  'Shakti Sena (Bharat Desh)': 2802.0,
#  'Shane Hind Fourm': 1306.0,
#  'Shiromani Akali Dal': 4042072.0,
#  'Shiromani Akali Dal (Amritsar)(Simranjit Singh Mann)': 100550.0,
#  'Shiromani Akali Dal (Taksali)': 10424.0,
#  'Shiromani Lok Dal Party': 984.0,
#  'Shivsena': 12852822.0,
#  'Shoshit Samaj Dal': 63543.0,
#  'Shri Janta Party': 1672.0,
#  'Sikkim Democratic Front': 154489.0,
#  'Sikkim Krantikari Morcha': 166922.0,
#  'Sikkim Republican Party': 1503.0,
#  'Sikkim United Front': 614.0,
#  'Smart Indians Party': 11877.0,
#  'Social Justice Party of India': 3927.0,
#  'Socialist Janata Party': 805.0,
#  'Socialist Party (India)': 3916.0,
#  'Subhashwadi Bhartiya Samajwadi Party (Subhas Party)': 3919.0,
#  'Suheldev Bharatiya Samaj Party': 313925.0,
#  'Sunder Samaj Party': 2568.0,
#  'Svatantra Bharat Satyagrah Party': 2142.0,
#  'Swabhiman Party': 2805.0,
#  'Swabhimani Paksha': 834380.0,
#  'Swaraj Party (Loktantrik)': 15132.0,
#  'Swarna Bharat Party': 5064.0,
#  'Swarnim Bharat Inquilab': 527.0,
#  'Swatantra Bharat Paksha': 12430.0,
#  'Swatantra Jantaraj Party': 25494.0,
#  'Swatantra Samaj Party': 2069.0,
#  'Tamil Maanila Congress  (Moopanar)': 220849.0,
#  'Tamil Nadu Ilangyar Katchi': 34233.0,
#  'Tamil Telugu National Party': 2516.0,
#  'Tamizhaga Murpokku Makkal Katchi': 3599.0,
#  'Telangana Communist Party of India': 1660.0,
#  'Telangana Jana Samithi': 57073.0,
#  'Telangana Prajala Party': 521.0,
#  'Telangana Rashtra Samithi': 7696848.0,
#  'Telangana Sakalajanula Party': 1048.0,
#  'Telangana Yuva Shakti': 3407.0,
#  'Telugu Desam': 12513061.0,
#  'The Future India Party': 820.0,
#  'The National Road Map Party of India': 4672.0,
#  'Tola Party': 330.0,
#  'Tripura Peoples Party': 2076.0,
#  'UTTARAKHAND PARIVARTAN PARTY': 5351.0,
#  'Ulzaipali Makkal Katchy': 9007.0,
#  'United Democratic Front Secular': 451.0,
#  'United Democratic Party': 267256.0,
#  'United People’s Party, Liberal': 416305.0,
#  'United States of India Party': 1244.0,
#  'Universal Brotherhood Movement': 689.0,
#  'Uttama Prajaakeeya Party': 120800.0,
#  'Uttar Pradesh Navnirman Sena': 2051.0,
#  'Uttarakhand Kranti Dal': 8830.0,
#  'Uttarakhand Kranti Dal (Democratic)': 12629.0,
#  'Uttarakhand Pragatisheel Party': 2041.0,
#  'VANCHITSAMAJ INSAAF PARTY': 3756.0,
#  'Vanchit Bahujan Aaghadi': 3743560.0,
#  'Vanchit Samaj Party': 13813.0,
#  'Viduthalai Chiruthaigal Katchi': 507643.0,
#  'Vikas Insaf Party': 3694.0,
#  'Vikassheel Insaan Party': 660706.0,
#  'Vishva SHakti Party': 8784.0,
#  'Vishwa Jana Party': 1726.0,
#  'Vishwa Manav Samaj Kalyan Parishad,': 1529.0,
#  'Vivasayigal Makkal Munnetra Katchi': 1108.0,
#  'Voters Party': 2478.0,
#  'Voters Party  International': 105972.0,
#  'Vyavastha Parivartan Party': 14974.0,
#  'Wazib Adhikar Party': 29392.0,
#  'Welfare Party Of India': 23035.0,
#  'Yekikrutha Sankshema Rashtriya Praja Party': 1320.0,
#  'Yuva Jan Jagriti Party': 10147.0,
#  'Yuva Krantikari Party': 30488.0,
#  'Yuva Sarkar': 1296.0,
#  'Yuva Vikas Party': 2858.0,
#  'Yuvajana Sramika Rythu Congress Party': 15534558.0}

# %%
Top_ten2019=pd.DataFrame({"PartyName":[i for i in CopyOfDict2019.keys()],"PartyVotes":[i for i in CopyOfDict2019.values()]})
Top_ten2019.sort_values(by=["PartyVotes"],ascending=False,inplace=True)
OriginalTopTen2019=Top_ten2019.head(10)
Labels2019=[]
ArrayLabels2019=(np.asarray(OriginalTopTen2019.PartyName))
X_axis2019=np.arange(len(OriginalTopTen2019.PartyName))
print(ArrayLabels2019)


plt.figure(figsize=(20,10))
plt.bar(X_axis2019,OriginalTopTen2019.PartyVotes)
plt.xlabel("Top 10 Party Names")
plt.ylabel("Total Votes in  Hundred Millions")
plt.xticks(X_axis2019,ArrayLabels2019)
plt.show()
# Out:
# ['BJP' 'INC' 'AITC' 'BSP' 'Independent2019' 'YSRCP' 'SP' 'DMK' 'Shivsena'
#  'TDP']

# %% [markdown]
# # Yearly Graphs For Party

# %%
AllPartyNames={}

for i in ArrayLabels:
    AllPartyNames[i]=[]

for i in ArrayLabels2009:
    AllPartyNames[i]=[]

for i in ArrayLabels2019:
    AllPartyNames[i]=[]
    


print(AllPartyNames)

for i in AllPartyNames.keys():
    if i in CopyOfDict2009:
        AllPartyNames[i].append(CopyOfDict2009[i])
        
    elif i not in CopyOfDict2009:
        
        AllPartyNames[i].append(0)
    if i in CopyOfDict:
        AllPartyNames[i].append(CopyOfDict[i])
        
    elif i not in CopyOfDict:
        AllPartyNames[i].append(0)  
        
    if i in CopyOfDict2019:
        AllPartyNames[i].append(CopyOfDict2019[i])
        
    elif i not in CopyOfDict2019:
        AllPartyNames[i].append(0)
    
    
    else:
        AllPartyNames[i].append(0)
print(AllPartyNames)

df=pd.DataFrame(AllPartyNames)
df=df.T


df.rename(columns={0:"2009",1:"2014",2:"2019"},inplace=True)
df


MyPlot=df.plot(x=df.index,y=["2009","2014","2019"],kind="bar",figsize=(20,10),title="2014 vs 2009 vs 2019",fontsize=15)
MyPlot.set_xlabel("Party Names")
MyPlot.set_ylabel("Total Votes in Hundred Millions")


for i in ([MyPlot.xaxis.label,MyPlot.yaxis.label,MyPlot.title]):
    i.set_fontsize(15)

plt.show()
# Out:
# {'BJP': [], 'INC': [], 'BSP': [], 'AITC': [], 'SP': [], 'ADMK': [], 'CPM': [], 'IND': [], 'TDP': [], 'YSRCP': [], 'NCP': [], 'DMK': [], 'Independent2019': [], 'Shivsena': []}
# {'BJP': [78435381.0, 161047761.0, 228011290.0], 'INC': [119111019.0, 96641749.0, 118787724.0], 'BSP': [25728920.0, 22434033.0, 22290771.0], 'AITC': [13356510.0, 21215661.0, 24929325.0], 'SP': [14284638.0, 18632568.0, 15261257.0], 'ADMK': [6953591.0, 18111579.0, 0], 'CPM': [22219111.0, 17938138.0, 0], 'IND': [21647686.0, 15888094.0, 0], 'TDP': [10481659.0, 14099230.0, 12513061.0], 'YSRCP': [0, 13995435.0, 15534558.0], 'NCP': [8521502.0, 8635558.0, 0], 'DMK': [7625397.0, 9631246.0, 13877622.0], 'Independent2019': [0, 0, 16273403.0], 'Shivsena': [0, 0, 12852822.0]}

# %% [markdown]
# # Model Creation and Prediction for 2014

# %%
from sklearn.cross_validation import train_test_split
Mse_Scores=[]
Rmse_Scores=[]

    
df=pd.read_csv("C:/Users/jivitesh's PC/Desktop/Indian Elections/General Elections/constituency_wise_detailed_results/2014.csv")
Predictiondf=pd.DataFrame({"GENERALVOTESSECURED":np.asarray(df.GENERALVOTESSECURED),"POSTALVOTESSECURED":np.asarray(df.POSTALVOTESSECURED),"PERCENTAGETOTALVOTES":np.asarray(df.PERCENTAGEOFTOTALVOTES),"PERCENTAGEOFTOTALPOLLED":np.asarray(df.PERCENTAGEOFTOTALPOLLED),"TOTALELECTORS":np.asarray(df.TOTALELECTORS),"TOTALVOTESSECURED":np.asarray(df.TOTALVOTESSECURED)})
Predictiondf.corr()
Predictiondf.columns

X=Predictiondf[['PERCENTAGEOFTOTALPOLLED',
        'POSTALVOTESSECURED', 'TOTALELECTORS','PERCENTAGETOTALVOTES']]
#X=Predictiondf[[
#        'POSTALVOTESSECURED','PERCENTAGETOTALVOTES']]

y=Predictiondf['TOTALVOTESSECURED']

X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.3,random_state=5)

lr=LinearRegression()
cv_results=model_selection.cross_val_score(lr,X_train,Y_train,cv=10,scoring="neg_mean_squared_error")
Mse_Scores=-cv_results
Rmse_Scores=np.sqrt(Mse_Scores)

lr.fit(X_train,Y_train)
lr.intercept_
CoeffDf=pd.DataFrame(lr.coef_,X.columns,columns=['Coeff'])
CoeffDf
print(Rmse_Scores.mean())

Predictions=lr.predict(X_test)
#print(Predictions)
#print(Y_test)
#print(Y_test-Predictions)
#(Predictiondf.corr())
plt.scatter(Y_test,Predictions)
plt.show()
# Out:
# 23243.614601723773

# %%
from sklearn.cross_validation import train_test_split
Mse_Scores=[]
Rmse_Scores=[]

    
df=pd.read_csv("C:/Users/jivitesh's PC/Desktop/Indian Elections/General Elections/VOTING_RESULTS_2019.csv")
Predictiondf=pd.DataFrame({"EVMVOTES":np.asarray(df.EVM_VOTES),"POSTALVOTES":np.asarray(df.POSTALVOTES),"VOTINGPERCENTAGE":np.asarray(df.VOTING_PERCENTAGE),"TOTALVOTES":np.asarray(df.TOTAL_VOTES)})
print(Predictiondf.corr())
Predictiondf.columns

X=Predictiondf[[
         'POSTALVOTES','VOTINGPERCENTAGE']]

y=Predictiondf['TOTALVOTES']

X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.3,random_state=5)

lr=LinearRegression()
cv_results=model_selection.cross_val_score(lr,X_train,Y_train,cv=10,scoring="neg_mean_squared_error")
Mse_Scores=-cv_results
Rmse_Scores=np.sqrt(Mse_Scores)

lr.fit(X_train,Y_train)
lr.intercept_
CoeffDf=pd.DataFrame(lr.coef_,X.columns,columns=['Coeff'])
CoeffDf
print(Rmse_Scores.mean())

Predictions=lr.predict(X_test)
#print(Predictions)
#print(Y_test)
#print(Y_test-Predictions)
#(Predictiondf.corr())
plt.scatter(Y_test,Predictions)
plt.show()
# Out:
#                   EVMVOTES  POSTALVOTES  TOTALVOTES  VOTINGPERCENTAGE
# EVMVOTES          1.000000    -0.022794    0.996734          0.978817
# POSTALVOTES      -0.022794     1.000000    0.058013         -0.021080
# TOTALVOTES        0.996734     0.058013    1.000000          0.975719
# VOTINGPERCENTAGE  0.978817    -0.021080    0.975719          1.000000
# 35118.312106300225

# %%
from sklearn.cross_validation import train_test_split
Mse_Scores=[]
Rmse_Scores=[]

    
df=pd.read_csv("C:/Users/jivitesh's PC/Desktop/Indian Elections/General Elections/constituency_wise_detailed_results/2009.csv")

Predictiondf=pd.DataFrame({"GENERALVOTESSECURED":np.asarray(df.GENERALVOTES),"POSTALVOTESSECURED":np.asarray(df.POSTALVOTES),"PERCENTAGETOTALVOTES":np.asarray(df.PERCENTAGEOFTOTALVOTES),"PERCENTAGEOFTOTALPOLLED":np.asarray(df.PERCENTAGEOFVOTESPOLLED),"TOTALELECTORS":np.asarray(df.TOTALELECTORS),"TOTALVOTESSECURED":np.asarray(df.TOTALVOTES)})
Predictiondf.corr()
Predictiondf.columns

X=Predictiondf[['PERCENTAGEOFTOTALPOLLED',
        'POSTALVOTESSECURED', 'TOTALELECTORS','PERCENTAGETOTALVOTES']]

y=Predictiondf['TOTALVOTESSECURED']

X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.3,random_state=5)

lr=LinearRegression()
cv_results=model_selection.cross_val_score(lr,X_train,Y_train,cv=10,scoring="neg_mean_squared_error")
Mse_Scores=-cv_results
Rmse_Scores=np.sqrt(Mse_Scores)

lr.fit(X_train,Y_train)
lr.intercept_
CoeffDf=pd.DataFrame(lr.coef_,X.columns,columns=['Coeff'])
CoeffDf
print(Rmse_Scores.mean())

Predictions=lr.predict(X_test)
#print(Predictions)
#print(Y_test)
#print(Y_test-Predictions)
#(Predictiondf.corr())
plt.scatter(Y_test,Predictions)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-da3364e1b661> in <module>()
#       6 df=pd.read_csv("C:/Users/jivitesh's PC/Desktop/Indian Elections/General Elections/constituency_wise_detailed_results/2009.csv")
#       7
# ----> 8 Predictiondf=pd.DataFrame({"GENERALVOTESSECURED":np.asarray(df.GENERALVOTES),"POSTALVOTESSECURED":np.asarray(df.POSTALVOTES),"PERCENTAGETOTALVOTES":np.asarray(df.PERCENTAGEOFTOTALVOTES),"PERCENTAGEOFTOTALPOLLED":np.asarray(df.PERCENTAGEOFVOTESPOLLED),"TOTALELECTORS":np.asarray(df.TOTALELECTORS),"TOTALVOTESSECURED":np.asarray(df.TOTALVOTES)})
#       9 Predictiondf.corr()
#      10 Predictiondf.columns
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'PERCENTAGEOFVOTESPOLLED'

# %%
from sklearn.cross_validation import train_test_split
Mse_Scores=[]
Rmse_Scores=[]

    
df=pd.read_csv("C:/Users/jivitesh's PC/Desktop/Indian Elections/General Elections/constituency_wise_detailed_results/2009And2014.csv")
Predictiondf=pd.DataFrame({"POSTALVOTESSECURED":np.asarray(df.POSTALVOTESSECURED),"PERCENTAGETOTALVOTES":np.asarray(df.PERCENTAGEOFTOTALVOTES),"PERCENTAGEOFTOTALPOLLED":np.asarray(df.PERCENTAGEOFTOTALPOLLED),"TOTALELECTORS":np.asarray(df.TOTALELECTORS),"TOTALVOTESSECURED":np.asarray(df.TOTALVOTESSECURED)})
Predictiondf.corr()
Predictiondf.columns

X=Predictiondf[['PERCENTAGEOFTOTALPOLLED',
        'POSTALVOTESSECURED', 'TOTALELECTORS','PERCENTAGETOTALVOTES']]
#X=Predictiondf[[
#        'POSTALVOTESSECURED','PERCENTAGETOTALVOTES']]

y=Predictiondf['TOTALVOTESSECURED']

X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.3,random_state=5)

lr=LinearRegression()
cv_results=model_selection.cross_val_score(lr,X_train,Y_train,cv=10,scoring="neg_mean_squared_error")
Mse_Scores=-cv_results
Rmse_Scores=np.sqrt(Mse_Scores)

lr.fit(X_train,Y_train)
lr.intercept_
CoeffDf=pd.DataFrame(lr.coef_,X.columns,columns=['Coeff'])
CoeffDf
print(Rmse_Scores.mean())

Predictions=lr.predict(X_test)
#print(Predictions)
#print(Y_test)
#print(Y_test-Predictions)
#(Predictiondf.corr())
plt.scatter(Y_test,Predictions)
plt.show()
# Out:
# 26474.26245576029

# %%
from sklearn.cross_validation import train_test_split
Mse_Scores=[]
Rmse_Scores=[]

    
df=pd.read_csv("C:/Users/jivitesh's PC/Desktop/Indian Elections/General Elections/constituency_wise_detailed_results/2019Specialised.csv")
Predictiondf=pd.DataFrame({"POSTALVOTESSECURED":np.asarray(df.POSTALVOTESSECURED),"PERCENTAGETOTALVOTES":np.asarray(df.PERCENTAGEOFTOTALVOTES),"TOTALVOTESSECURED":np.asarray(df.TOTALVOTESSECURED)})
Predictiondf.corr()
Predictiondf.columns

X=Predictiondf[[
        'POSTALVOTESSECURED','PERCENTAGETOTALVOTES']]
#X=Predictiondf[[
#        'POSTALVOTESSECURED','PERCENTAGETOTALVOTES']]

y=Predictiondf['TOTALVOTESSECURED']

X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.3,random_state=5)

lr=LinearRegression()
cv_results=model_selection.cross_val_score(lr,X_train,Y_train,cv=10,scoring="neg_mean_squared_error")
Mse_Scores=-cv_results
Rmse_Scores=np.sqrt(Mse_Scores)

lr.fit(X_train,Y_train)
lr.intercept_
CoeffDf=pd.DataFrame(lr.coef_,X.columns,columns=['Coeff'])
CoeffDf
print(Rmse_Scores.mean())

Predictions=lr.predict(X_test)
#print(Predictions)
#print(Y_test)
#print(Y_test-Predictions)
#(Predictiondf.corr())
plt.scatter(Y_test,Predictions)
plt.show()
# Out:
# 36549.75956665211

# %%
df=pd.read_csv("C:/Users/jivitesh's PC/Desktop/Indian Elections/General Elections/constituency_wise_detailed_results/2009.csv")
df
# Out:
#       PERCENTAGEOFTOTALVOTES   PERCENTAGEOFVOTESPOLLED  AGE  \
# 0                       5.12                      6.71   55
# 1                      22.74                     29.78   39
# 2                      32.91                     43.11   43
# 3                       1.46                      1.91   50
# 4                       9.98                     13.08   59
# 5                       0.69                      0.91   47
# 6                       1.18                      1.55   36
# 7                       0.81                      1.06   39
# 8                       1.45                      1.90   55
# 9                       1.21                      1.75   49
# 10                     20.12                     29.28   41
# 11                      5.16                      7.50   64
# 12                     23.85                     34.70   51
# 13                     13.35                     19.42   36
# 14                      0.44                      0.64   39
# 15                      0.64                      0.93   38
# 16                      0.30                      0.44   36
# 17                      0.26                      0.38   42
# 18                      0.34                      0.49   39
# 19                      0.35                      0.50   32
# 20                      0.25                      0.37   38
# 21                      0.42                      0.61   51
# 22                      0.51                      0.74   51
# 23                      1.54                      2.24   41
# 24                      8.18                     12.37   75
# 25                     21.25                     32.14   41
# 26                     17.89                     27.06   49
# 27                      1.09                      1.65   58
# 28                      0.22                      0.33   40
# 29                      0.29                      0.44   39
# ...                      ...                       ...  ...
# 8040                    0.53                      0.62   57
# 8041                   39.78                     46.32   60
# 8042                   27.36                     34.32   59
# 8043                    0.48                      0.61   48
# 8044                   39.40                     49.41   61
# 8045                    1.76                      2.21   56
# 8046                    6.90                      8.66   54
# 8047                    0.07                      0.09   59
# 8048                    0.06                      0.08   38
# 8049                    0.11                      0.14   50
# 8050                    0.08                      0.10   29
# 8051                    0.09                      0.11   27
# 8052                    0.08                      0.10   32
# 8053                    0.24                      0.30   40
# 8054                    0.09                      0.11   45
# 8055                    0.27                      0.34   40
# 8056                    0.19                      0.23   36
# 8057                    0.67                      0.84   32
# 8058                    0.32                      0.40   32
# 8059                    0.10                      0.12   36
# 8060                    0.25                      0.31   35
# 8061                    0.05                      0.06   46
# 8062                    0.05                      0.06   45
# 8063                    0.06                      0.07   59
# 8064                    0.20                      0.25   31
# 8065                    0.04                      0.05   46
# 8066                    0.05                      0.06   42
# 8067                    0.55                      0.69   60
# 8068                    0.06                      0.07   32
# 8069                    0.16                      0.20   34
#
#                    CANDIDATE CATEGORY  GENERALVOTES    PARTY  POSTALVOTES SEX  \
# 0                ADE TUKARAM       ST         57856      BJP           75   M
# 1              KOTNAK RAMESH       ST        257137      INC           44   M
# 2              RATHOD RAMESH       ST        372154      TDP          114   M
# 3       RATHOD SADASHIV NAIK       ST         16471      BSP            0   M
# 4            MESRAM NAGO RAO       ST        112914     PRAP           16   M
# 5          ATHRAM LAXMAN RAO       ST          7824      IND            0   M
# 6             GANTA PENTANNA       ST         13377      IND            1   M
# 7            NETHAVAT RAMDAS       ST          9157      IND            0   M
# 8             BANKA SAHADEVU       ST         16440      IND            1   M
# 9              GAJJELA SWAMY       SC         15852      BSP            7   M
# 10           GOMASA SRINIVAS       SC        264193      TRS          538   M
# 11          MATHANGI NARSIAH       SC         67640      BJP          196   M
# 12           DR.G.VIVEKANAND       SC        313276      INC          472   M
# 13       AREPELLI DAVID RAJU       SC        175491     PRAP          114   M
# 14           KRISHNA SABBALI       SC          5751  MCPI(S)            1   M
# 15           AMBALA MAHENDAR       SC          8362      IND            2   M
# 16              A. KAMALAMMA       SC          3937      IND            1   F
# 17              GORRE RAMESH       SC          3413      IND            1   M
# 18         NALLALA KANUKAIAH       SC          4465      IND            3   M
# 19               B. MALLAIAH       SC          4539      IND            2   M
# 20              K. RAJASWARI       SC          3326      IND            2   F
# 21                 D. RAMULU       SC          5511      IND            0   M
# 22             G.VINAY KUMAR       SC          6718      IND            8   M
# 23                S.LAXMAIAH       SC         20263      IND            0   M
# 24         CHANDUPATLA JANGA      GEN        121527      BJP          810   M
# 25          PONNAM PRABHAKAR      GEN        316702      INC         1225   M
# 26    VINOD KUMAR BOINAPALLY      GEN        266523      TRS         1161   M
# 27         VIRESHAM NALIMELA      GEN         16298      BSP           34   M
# 28             RAGULA RAMULU       SC          3277   RPI(A)            2   M
# 29      LINGAMPALLI SRINIVAS      GEN          4398  MCPI(S)            1   M
# ...                      ...      ...           ...      ...          ...  ..
# 8040     DR. K. P. MUTHUKOYA       ST           245      BJP            0   M
# 8041        DR. POOKUNHIKOYA       ST         18294      NCP            0   M
# 8042             RAMADASS. M      GEN        208615      PMK            4   M
# 8043         M. SOMASUNDARAM       SC          3697      BSP            0   M
# 8044            NARAYANASAMY      GEN        300366      INC           25   M
# 8045          VISWESWARAN. M      GEN         13442      BJP            0   M
# 8046           K.A.U. ASANAA      GEN         52637     DMDK            1   M
# 8047          S. GOVINDASAMY      GEN           570      KDC            0   M
# 8048             S. GNANAVEL       SC           456      JMM            0   M
# 8049      S. BALASUBRAMANIAN      GEN           839  CPI(ML)            0   M
# 8050        PRADEEP ANIRUDDH      GEN           627     PPOI            0   M
# 8051            A. RAJASEKAR      GEN           656      LJP            0   M
# 8052          ARUNACHALAM. K       SC           597      IND            0   M
# 8053            V. RAJENDRAN      GEN          1810      IND            0   M
# 8054           V. RAMAMURTHY      GEN           662      IND            0   M
# 8055          KALIAMURTHY. K       SC          2074      IND            0   M
# 8056            V. SARAVANAN       SC          1425      IND            0   M
# 8057           M. CHITTIBABU      GEN          5103      IND            0   M
# 8058            SIVARAMAN. V      GEN          2439      IND            0   M
# 8059         G. SUBRAMANIYAN      GEN           757      IND            0   M
# 8060             A. SENKADIR      GEN          1896      IND            0   M
# 8061              I.M. SEKAR      GEN           375      IND            0   M
# 8062  MUPPADAI MATHIMAHARAJA      GEN           378      IND            0   M
# 8056     15        1425   Puducherry      Puducherry         762440
# 8057     16        5103   Puducherry      Puducherry         762440
# 8058     17        2439   Puducherry      Puducherry         762440
# 8059     18         757   Puducherry      Puducherry         762440
# 8060     19        1896   Puducherry      Puducherry         762440
# 8061     20         375   Puducherry      Puducherry         762440
# 8062     21         378   Puducherry      Puducherry         762440
# 8063     22         422   Puducherry      Puducherry         762440
# 8064     23        1532   Puducherry      Puducherry         762440
# 8065     24         298   Puducherry      Puducherry         762440
# 8066     25         378   Puducherry      Puducherry         762440
# 8067     26        4179   Puducherry      Puducherry         762440
# 8068     27         449   Puducherry      Puducherry         762440
# 8069     28        1239   Puducherry      Puducherry         762440
#
#       TOTAL GENERAL VOTES POLLED  TOTAL VOTES POLLED  \
# 0                         863330              863581
# 1                         863330              863581
# 2                         863330              863581
# 3                         863330              863581
# 4                         863330              863581
# 5                         863330              863581
# 6                         863330              863581
# 7                         863330              863581
# 8                         863330              863581
# 9                         902737              904084
# 10                        902737              904084
# 11                        902737              904084
# 12                        902737              904084
# 13                        902737              904084
# 14                        902737              904084
# 15                        902737              904084
# 16                        902737              904084
# 17                        902737              904084
# 18                        902737              904084
# 19                        902737              904084
# 20                        902737              904084
# 21                        902737              904084
# 22                        902737              904084
# 23                        902737              904084
# 24                        985840              989301
# 25                        985840              989301
# 26                        985840              989301
# 27                        985840              989301
# 28                        985840              989301
# 29                        985840              989301
# ...                          ...                 ...
# 8040                       39498               39498
# 8041                       39498               39498
# 8042                      607918              607948
# 8043                      607918              607948
# 8044                      607918              607948
# 8045                      607918              607948
# 8046                      607918              607948
# 8047                      607918              607948
# 8048                      607918              607948
# 8049                      607918              607948
# 8050                      607918              607948
# 8051                      607918              607948
# 8052                      607918              607948
# 8053                      607918              607948
# 8054                      607918              607948
# 8055                      607918              607948
# 8056                      607918              607948
# 8057                      607918              607948
# 8058                      607918              607948
# 8059                      607918              607948
# 8060                      607918              607948
# 8061                      607918              607948
# 8062                      607918              607948
# 8063                      607918              607948
# 8064                      607918              607948
# 8065                      607918              607948
# 8066                      607918              607948
# 8067                      607918              607948
# 8068                      607918              607948
# 8069                      607918              607948
#
#       TOTAL POSTAL VOTES POLLED
# 0                           251
# 1                           251
# 2                           251
# 3                           251
# 4                           251
# 5                           251
# 6                           251
# 7                           251
# 8                           251
# 9                          1347
# 10                         1347
# 11                         1347
# 12                         1347
# 13                         1347
# 14                         1347
# 15                         1347
# 16                         1347
# 17                         1347
# 18                         1347
# 19                         1347
# 20                         1347
# 21                         1347
# 22                         1347
# 23                         1347
# 24                         3461
# 25                         3461
# 26                         3461
# 27                         3461
# 28                         3461
# 29                         3461
# ...                         ...
# 8040                          0
# 8041                          0
# 8042                         30
# 8043                         30
# 8044                         30
# 8045                         30
# 8046                         30
# 8047                         30
# 8048                         30
# 8049                         30
# 8050                         30
# 8051                         30
# 8052                         30
# 8053                         30
# 8054                         30
# 8055                         30
# 8056                         30
# 8057                         30
# 8058                         30
# 8059                         30
# 8060                         30
# 8061                         30
# 8062                         30
# 8063                         30
# 8064                         30
# 8065                         30
# 8066                         30
# 8067                         30
# 8068                         30
# 8069                         30
#
# [8070 rows x 17 columns]

# %%
data=[['Anav','Jivi',20],['Jivi','Anav',15],['Utsav','Utsav',15],['Etaash','Anav',10],['Viraat','Viraat',30],['Rohit','Rohit',40],['Yash','Yash',15],['NA','Yash',50],['NA','Anav',123],['NA','Jivi',10],['NA','Etaash',15],['NA','Jivi',10],['Jivi','NA',15],['Anav','Jivi',20],['Jivi','Anav',15],['Utsav','Utsav',15],['Etaash','Anav',10],['Viraat','Viraat',30],['Rohit','Rohit',40],['Yash','Yash',15],['NA','Yash',50],['NA','Anav',123],['NA','Jivi',10],['NA','Etaash',15],['NA','Jivi',10],['Jivi','NA',15]]
df=pd.DataFrame(data,columns=['UniqueName','OrderedName','Total'])



UniqueNameArray=[i for i in (df.UniqueName)]
OrderedNames=[]
NameTotal={}
AllIndexes={}
UniqueNameArray=set(UniqueNameArray)

np.asarray(UniqueNameArray)
for i in UniqueNameArray:
    NameTotal[i]=0
    
for i in range (len(df.OrderedName)):
        OrderedNames.append(df.OrderedName[i])
np.asarray(OrderedNames)

print(df)
#print(OrderedNames)
#print(UniqueNameArray)
#print(NameTotal)
#print(AllIndexes)
UniqueNameArray=set(UniqueNameArray)

#print(NameTotal)

#print(AllIndexes)

UniqueNameArray=list(UniqueNameArray)
print(UniqueNameArray)
   
for i in NameTotal.keys():
    AllIndexes[i]=np.where(df.OrderedName==i)[0]

#print(AllIndexes)

def SumTotal(target):
    for x in AllIndexes[target]:
        NameTotal[target]=NameTotal[target]+df.Total[x]
    return NameTotal

for i in range(len(UniqueNameArray)-1):
    for j in df.OrderedName:
        if UniqueNameArray[i]==j :
            SumTotal(j)

for i in NameTotal.keys():
    NameTotal[i]=NameTotal[i]/OrderedNames.count(i)
        
print(NameTotal)
        
Copy=NameTotal[:]
# Out:
#    UniqueName OrderedName  Total
# 0        Anav        Jivi     20
# 1        Jivi        Anav     15
# 2       Utsav       Utsav     15
# 3      Etaash        Anav     10
# 4      Viraat      Viraat     30
# 5       Rohit       Rohit     40
# 6        Yash        Yash     15
# 7          NA        Yash     50
# 8          NA        Anav    123
# 9          NA        Jivi     10
# 10         NA      Etaash     15
# 11         NA        Jivi     10
# 12       Jivi          NA     15
# 13       Anav        Jivi     20
# 14       Jivi        Anav     15
# 15      Utsav       Utsav     15
# 16     Etaash        Anav     10
# 17     Viraat      Viraat     30
# 18      Rohit       Rohit     40
# 19       Yash        Yash     15
# 20         NA        Yash     50
# 21         NA        Anav    123
# 22         NA        Jivi     10
# 23         NA      Etaash     15
# 24         NA        Jivi     10
# 25       Jivi          NA     15
# ['Jivi', 'Viraat', 'Utsav', 'NA', 'Etaash', 'Anav', 'Yash', 'Rohit']
# {'Jivi': 80.0, 'NA': 30.0, 'Viraat': 60.0, 'Etaash': 30.0, 'Anav': 296.0, 'Yash': 130.0, 'Rohit': 0.0, 'Utsav': 30.0}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-9ee0ab524e5a> in <module>()
#      52 print(NameTotal)
#      53
# ---> 54 Copy=NameTotal[:]
#      55
#      56
#
# TypeError: unhashable type: 'slice'
